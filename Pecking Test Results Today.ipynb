# %% [markdown]
# Run this notebook to obtain the results of today's tests for the list of birds BIRDS

# %%
BIRDS = ['HpiPur058093M', 'BluYel037018F', 'HpiRed004141M', 'PurWhi127037F']

import datetime
from datetime import date
import glob
import os
import re
import sys
from contextlib import contextmanager

import ipywidgets as widgets
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from IPython.display import display, HTML, clear_output
from ipywidgets import interact, interactive
from scipy.stats import fisher_exact

from pecking_analysis.peck_data import (
    load_pecking_days,
    get_labels_by_combining_columns,
    plot_data,
    peck_data,
    color_by_reward,
    windows_by_reward,
    get_dates,
    PythonCSV
)

pd.options.display.float_format = '{:,.4f}'.format

import warnings
warnings.filterwarnings('ignore')

# %load_ext autoreload
# %autoreload 2

@contextmanager
def block_print():
    sys.stdout = open(os.devnull, 'w')
    yield 
    sys.stdout = sys.__stdout__
    
# Getting the data for today's birds    
DATADIR = "/data/pecking_test/behavior/"

data = pd.DataFrame()
for bird in BIRDS:
    today = date.today()
    blocks, stim_blocks = load_pecking_days(os.path.join(DATADIR, bird, today.strftime("%d%m%y")))
    data = data.append(peck_data(blocks))
with block_print():
        display(HTML(data.to_html()))
# Out:
# /home/fet/code/pecking_analysis/env/lib/python3.9/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.2' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th colspan="4" halign="left">Total</th>
#       <th colspan="2" halign="left">Percent</th>
#       <th colspan="3" halign="left">Interrupt</th>
#       <th colspan="2" halign="left">Stats</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th>Rewarded</th>
#       <th>Trials</th>
#       <th>Unrewarded</th>
#       <th>Feeds</th>
#       <th>Rewarded</th>
#       <th>Unrewarded</th>
#       <th>Total</th>
#       <th>Rewarded</th>
#       <th>Unrewarded</th>
#       <th>Z-Score</th>
#       <th>P-Value</th>
#     </tr>
#     <tr>
# ...
